# %% [markdown]
# # Data Collection
# - The data required for a research can be primary or secondary in nature. Primary data, by definition is the data that has been collected first hand by the researcher specially for addressing the population at hand.
# - Secondary data is data collected by someone other than the actual user. It means that the information is already available, and someone analyses it. The secondary data includes magazines, newspapers, books, journals, etc. It may be either published data or unpublished data.

# %% [markdown]
# # Categorization of Data
# -  There are two types of the data:
#     1. Quantative Data Type
#     2. Qualitative Data Type
# 1. Quantative Data Type:
# - It consists of numerical data.
# - Under the quantative data type, we have another two types of data, that is,
#     - Discrete Data Type
#     - Continous Data Type
#         1. Discrete Data Type: This type of data is realated to the count, as in, whatever we can count, can be regarded as discrete data types. For example, number of student in a class.
#         2. Continous Data Type: This is measurable data, it means this kind of data can be measured, rather than counting. It can take continous values. For example, weights of the student in a class.
# 2. Qualitative Data Type:
# - It consists of attributes, labels or non-numerical data.
# - Under this data type we have two types, that is,
#     - Ordinal Data Type
#     - Nominal Data Type
#         1. Ordinal Data Type: This type of data deals with the order to the attributes, labels or non-numerical data. For example, grade given to the student in an examination, can be categorized as a ordinal data type.
#         2. Nominal Data Type: This is second type of qualitative data type, where order is not maintained. For example, color of hairs of a student.

# %% [markdown]
# # Presentation of Data
# - As soon as the data collection is over, the investigator needs to find a way of presenting the data in a meaningful, efficient and easily understood way to identify the main features of the data at a glance using a suitable presentation method. Generally, the data in the statistics can be presented in three different forms, such as textual method, tabular method and graphical method.
#     - Textual Method
#         -> It is simple method, just to write down the data in a row or array format, as collected and perform the statistics needed.
#     - Tabular Method
#         -> It is a step a head of textual method, as it is presented in table format. So it makes easy to visualise and work with less errors.
#     - Graphical Method
#         -> It is one more step ahead of tabular method, as it shows the spread of the data, as well as the other statistics functions.

# %% [markdown]
# # Measures of Central Tendency
# 1. Mean
# 2. Mode
# 3. Median
#
#     1. **Mean**: It actually represents the average of the given collection of data. It is applicable for both continuous and discrete data. It is equal to the sum of all the values in the collection of data divided by the total number of values.
#     2. **Mode**: The most frequent number occurring in the data set is known as the mode.
#     3. **Median**: Generally median represents the mid-value of the given set of data when arranged in a particular order. Given that the data collection is arranged in ascending or descending order, the following method is applied:
#         - If number of values or observations in the given data is odd, then the median is given by, (n+1)th/2.
#         - If in the given data set, the number of values or observations is even then the median is given by the average of nth/2 and (n+1)th/2.

# %%
import numpy as np
lis = [ 1, 2, 2, 3, 3, 3, 4, 4, 5, 6, 7]
np.mean(lis)
# Out:
# 3.6363636363636362

# %%
np.median(lis)
# Out:
# 3.0

# %%
import scipy.stats as st
st.mode(lis)
# Out:
# ModeResult(mode=array([3]), count=array([3]))

# %%
import statistics
statistics.mode(lis)
# Out:
# 3

# %% [markdown]
# # Measure of Dispersion
# 1. Range
# 2. Variance
# 3. Standard Deviation
#     1. **Range**: The range of the data is given as the difference between the maximum and the minimum values of the observations in the data.
#     2. **Variance**: The variance of the data is given by measuring the distance of the observed values from the mean of the distribution.
#     3. **Standard Deviation**: In the calculation of variance, notice that the units of the variance and the unit of the observations are not the same.

# %%
rang = np.max(lis) - np.min(lis)
rang
# Out:
# 6

# %%
np.var(lis)
# Out:
# 2.958677685950413

# %%
np.std(lis)
# Out:
# 1.7200807207658637

# %% [markdown]
# # Linear Algebra
# 1. Scalars
# 2. Vectors
# 3. Matrices
# 4. Operation on Matrices
# 5. Vector Addition & Vector Multiplication
# 6. Transpose and Inverse
# 7. Eigenvalues and Eigenvectors
# 8. Rank of matrix
#     1. **Scalars**: A scalar quantity is defined as the physical quantity with only magnitude and no direction. Such physical quantities can be described just by their numerical value without directions.
#     2. **Vectors**: A vector quantity is defined as the physical quantity that has both directions as well as magnitude. A vector with the value of magnitude equal to one is called a unit vector and is represented by a lowercase alphabet with a “hat” circumflex i.e. “û“.
#     3. **Matrices**: A matrix is a rectangular array of numbers that is usually named by a capital letter: A,B,C,and so on. Each entry in a matrix is referred to as aij, such that i represents the row and j represents the column. Matrices are often referred to by their dimensions: m×n indicating m rows and n columns.
#     4. **Operation on matrices**: There are varios operation on matrices some of it are addition, subtraction, multiplication, and division.
#     5. **Vector Addition & Vector Multiplication**:Vector addition means putting two or more vectors together. In the addition of vectors, we are adding two or more vectors using the addition operation in order to obtain a new vector that is equal to the sum of the vectors. Vectors can be added only if they are of the same nature. For instance, acceleration should be added with only acceleration and not mass. The vector multiplication is somewhat similar to cross product, b x c = |b||c|sin(theta).
#     6. **Transpose & Inverse**: The transpose of a matrix is found by interchanging its rows into columns or columns into rows. The transpose of the matrix is denoted by using the letter “T” in the superscript of the given matrix. If A is a non-singular square matrix, there is an existence of n x n matrix A-1, which is called the inverse matrix of A such that it satisfies the property: AA-1 = A-1A = I, where I is  the Identity matrix.
#     7. **Eigenvalues and Eigenvectors**: Let A be nxn matrix. The eigenvalues of A are the roots of the characteristics polynomials p(lambda) = det(A - lambda x I). For each eigenvalues, we find eigenvectors `v = [v1, v2, ..]` by solving the linear system ( A - lambda x I) v = 0.
#     8. **Rank of matrix**: Rank of the matrix is the number of linearly independent rows or the number of linearly independent columns.

# %%
import numpy as np
import scipy.linalg as la

# %%
a= np.array([[3,4],[2,-2]])
b= np.array([12,1])
la.solve(a,b)
# Out:
# array([2. , 1.5])

# %%
np.linalg.solve(a,b)
# Out:
# array([2. , 1.5])

# %%
## creating matrix
A= np.array([[3,5,7],[2,4,6],[1,2,3]])
A
# Out:
# array([[3, 5, 7],
#        [2, 4, 6],
#        [1, 2, 3]])

# %%
## Transpose matrix
A.T
# Out:
# array([[3, 2, 1],
#        [5, 4, 2],
#        [7, 6, 3]])

# %%
## Multiplication of positinal values
A*(A.T)
# Out:
# array([[ 9, 10,  7],
#        [10, 16, 12],
#        [ 7, 12,  9]])

# %%
## A*B 
B = np.array([1,4,7]).reshape(3,1)
B
# Out:
# array([[1],
#        [4],
#        [7]])

# %%
## Multiplication of positinal values
A*B
# Out:
# array([[ 3,  5,  7],
#        [ 8, 16, 24],
#        [ 7, 14, 21]])

# %%
np.multiply(A, B)
# Out:
# array([[ 3,  5,  7],
#        [ 8, 16, 24],
#        [ 7, 14, 21]])

# %%
np.matmul(A,B)
# Out:
# array([[72],
#        [60],
#        [30]])

# %%
## A^2 - using matrix multiplication
np.matmul(A, A.T)
# Out:
# array([[83, 68, 34],
#        [68, 56, 28],
#        [34, 28, 14]])

# %%
B = np.array([[2,4,5],[1,3,6],[1,4,3]])
B
# Out:
# array([[2, 4, 5],
#        [1, 3, 6],
#        [1, 4, 3]])

# %%
## Determination of the matrix
la.det(B)
# Out:
# -13.000000000000002

# %%
a1 = np.array([4,4,3,-2]).reshape(2,2)
b1 = np.array([16,2])
la.solve(a1,b1)
# Out:
# array([2., 2.])

# %%
# dot prodcut of two vectors
np.dot(b,b1)
# Out:
# 194

# %%
a4 = np.array([1,2,3,4]).reshape(2,2)
a4
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
eigen_val, eigen_vec= la.eig(a4)

# %%
eigen_val
# Out:
# array([-0.37228132+0.j,  5.37228132+0.j])

# %%
eigen_vec
# Out:
# array([[-0.82456484, -0.41597356],
#        [ 0.56576746, -0.90937671]])

# %% [markdown]
# # Probability Distributions
# 1. Binomial Distribution
# 2. Poisson Distribution
# 3. Normal Distribution
#     1. **Binomial Distribution**: In binomial probability distribution, the number of ‘Success’ in a sequence of n experiments, where each time a question is asked for yes-no, then the boolean-valued outcome is represented either with success/yes/true/one (probability p) or failure/no/false/zero (probability q = 1 − p).
#     2. **Poisson Distribution**: The Poisson distribution is a discrete probability function that means the variable can only take specific values in a given list of numbers, probably infinite. A Poisson distribution measures how many times an event is likely to occur within “x” period of time. In other words, we can define it as the probability distribution that results from the Poisson experiment. A Poisson experiment is a statistical experiment that classifies the experiment into two categories, such as success or failure. Poisson distribution is a limiting process of the binomial distribution.
#     3. **Normal Distribution**: The Normal Distribution is defined by the probability density function for a continuous random variable in a system. Let us say, f(x) is the probability density function and X is the random variable. Hence, it defines a function which is integrated between the range or interval (x to x + dx), giving the probability of random variable X, by considering the values between x and x+dx.

# %% [markdown]
# ## Binomial Distribution
# #### When you toss a coin 3 times, what is
# 1. the probability thet you get 0, 1, 2, & 3 heads?
# 2. the probability that you get atmost 2 heads?
# 3. the probability that you get at least 3 heads?

# %%
## probability mass function (pmf) values
x = np.arange(0,4)
n = 3
p = 0.5
st.binom.pmf(x,n,p)
# Out:
# array([0.125, 0.375, 0.375, 0.125])

# %%
## Cumalative probability: cdf
cdf = st.binom.cdf(x,n,p)
cdf
# Out:
# array([0.125, 0.5  , 0.875, 1.   ])

# %%
## p(x<=2) = p(x=0) + p(x=1) + p(x=2)
x= [0, 1, 2]
st.binom.pmf(x,n,p).sum()
# Out:
# 0.8750000000000002

# %%
# cdf gives the area from the left hand side
st.binom.cdf(2,n,p)
# Out:
# 0.875

# %%
# sf gives the area form the right hand side.
1 - st.binom.sf(2,n,p)
# Out:
# 0.875

# %% [markdown]
# ## Poisson Distribution
#
# #### A bank recieves an average of 5 bad cheques a day.
#
# - What is the probability that will recieve
# 1. 3 bad cheques on a particular day?
# 2. 4 bad cheques on a particular day?
# 3. 5 bad cheques on a particular day?

# %%
lamda = 5
# 1
x = 3
st.poisson.pmf(x, lamda)
# Out:
# 0.1403738958142805

# %%
# 2
st.poisson.pmf(4, lamda)
# Out:
# 0.17546736976785063

# %%
# 2
st.poisson.pmf(5, lamda)
# Out:
# 0.17546736976785068

# %% [markdown]
# ## Normal Distribution
#
# #### A bank manager has learnt that the length of time the customers have to wait for being attended by the teller is normally distributed with mean time of 5 minutes and standard deviation of 0.8 minutes. Find the probability that a customer has to wait:
# 1. for less than 6 min
# 2. for more than 3.5 min and
# 3. between 3.4 and 6.2 min.

# %%
mu = 5
sigma = 0.8
# 1
st.norm.cdf(6,mu, sigma)
# Out:
# 0.8943502263331446

# %%
# 2
st.norm.sf(3.5, mu, sigma)
# Out:
# 0.9696036382347386

# %%
# 3
st.norm.cdf(6.2,mu,sigma) - st.norm.cdf(3.4,mu,sigma)
# Out:
# 0.9104426667829627

# %% [markdown]
# # Conditional Probability & Bayes Theorem
# 1. **Conditional Probability**: Conditional probability is the probability of an event occurring given that another event has already occurred. The concept is one of the quintessential concepts in probability theory. Note that conditional probability does not state that there is always a causal relationship between the two events, as well as it does not indicate that both events occur simultaneously.
#                 P(A|B) = P(A intersection B)
#                          ------------------
#                                 P(B)
# 2. **Bayes Theorem**: Let E1, E2,…, En be a set of events associated with a sample space S, where all the events E1, E2,…, En have nonzero probability of occurrence and they form a partition of S. Let A be any event associated with S, then according to Bayes theorem,
#                 P(Ei|A) =      P(Ei)P(A|Ei)
#                           ---------------------
#                           Summation P(Ek)P(A|Ek)

# %% [markdown]
# # Central Limit Theorem
# - The central limit theorem states that the sampling distribution of a sample mean is approximately normal if the sample size is large enough, even if the population distribution is not normal.
# - The central limit theorem also states that the sampling distribution will have the following properties:
#     - The mean of the sampling distribution will be equal to the mean of the population distribution.
#     - The variance of the sampling distribution will be equal to the variance of the population distribution divided by the sample size.

# %% [markdown]
# # Introduction to Sampling
#
# ## There are two kinds of sampling method.
# 1. **Probability Sampling Methods**: The first class of sampling methods is known as probability sampling methods because every member in a population has an equal probability of being selected to be in the sample.
#     1. **Simple Random Sample**: Every member of a population has an equal chance of being selected to be in the sample. Randomly select members through the use of a random number generator or some means of random selection. We put the names of every student in a class into a hat and randomly draw out names to get a sample of students.
#     2. **Stratified random sample**: Split a population into groups. Randomly select some members from each group to be in the sample. Split up all students in a school according to their grade – freshman, sophomores, juniors, and seniors. Ask 50 students from each grade to complete a survey about the school lunches.
#     3. **Cluster random sample**: Split a population into clusters. Randomly select some of the clusters and include all members from those clusters in the sample. A company that gives whale watching tours wants to survey its customers. Out of ten tours they give one day, they randomly select four tours and ask every customer about their experience.
#     4. **Systematic random sample**: Put every member of a population into some order. Choosing a random starting point and select every nth member to be in the sample. A teacher puts students in alphabetical order according to their last name, randomly chooses a starting point, and picks every 5th student to be in the sample.
# 2. **Non-probability Sampling Methods**: Another class of sampling methods is known as non-probability sampling methods because not every member in a population has an equal probability of being selected to be in the sample. This type of sampling method is sometimes used because it’s much cheaper and more convenient compared to probability sampling methods. It’s often used during exploratory analysis when researchers simply want to gain an initial understanding of a population. However, the samples that result from these sampling methods cannot be used to draw inferences about the populations they came from because they typically aren’t representative samples.
#     1. **Convenience sample**: Choose members of a population that are readily available to be included in the sample. Location and time of day will affect the results. More than likely, the sample will suffer from undercoverage bias since certain people (e.g. those who work during the day) will not be represented as much in the sample.
#     2. **Voluntary response sample**:  A researcher puts out a request for volunteers to be included in a study and members of a population voluntarily decide to be included in the sample or not. People who voluntarily respond will likely have stronger opinions (positive or negative) than the rest of the population, which makes them an unrepresentative sample. Using this sampling method, the sample is likely to suffer from nonresponse bias – certain groups of people are simply less likely to provide responses.
#     3. **Snowball sample**: Researchers recruit initial subjects to be in a study and then ask those initial subjects to recruit additional subjects to be in the study. Using this approach, the sample size “snowballs” bigger and bigger as each additional subject recruits more subjects. Sampling bias is likely to occur. Because initial subjects recruit additional subjects, it’s likely that many of the subjects will share similar traits or characteristics that might be unrepresentative of the larger population under study. Thus, findings from the sample can’t be extrapolated to the population.
#     4. **Purposive sample**: Researchers recruit individuals based on who they think will be most useful based on the purpose of their study. The individuals in the sample are unlikely to be representative of the overall population. Thus, findings from the sample can’t be extrapolated to the population.

# %%
## Simple Random Sampling - Without Replacement
import scipy.stats as st
np.random.seed(30)
population = st.norm.rvs(25, 6, 100)
population
# Out:
# array([17.41568401, 34.16743211, 19.17573437, 27.8233577 , 24.3958197 ,
#        26.82275911, 14.64422543, 34.51057221, 25.80577956, 18.3588672 ,
#        34.46935329, 25.64498766, 20.41571304, 20.34886894, 33.30308299,
#        29.56231051, 23.28612692, 28.23020486, 12.49662021, 30.62669026,
#        24.96533202, 22.1951262 , 22.46190821, 31.38689256,  7.57979442,
#        34.70134225, 33.55305931, 21.01146929, 30.91010716, 14.79720841,
#        18.39913716, 17.10613546, 29.86300546, 18.73132976, 20.86462376,
#        19.88345881, 31.68083265, 13.47298169, 20.79158549, 30.0945271 ,
#        31.30419873, 21.77875327, 24.82484369, 33.36433591, 22.61279535,
#        31.11476431, 36.3932878 , 22.87090214, 22.67790118, 13.43616769,
#        28.30453955, 30.72613488, 29.69665902, 14.24057259, 32.45113298,
#        35.24648126, 26.93892038, 19.04899363, 18.02030577, 24.8719894 ,
#        15.50802825, 17.54131489, 22.53898586, 18.66954797, 18.65612714,
# ...

# %%
## Random Sampling without Replacement
import random
random.seed(10)
sample = random.sample(list(population), k = 30)
print(sample)
# Out:
# [23.70007093372968, 24.395819701170865, 32.45113297830268, 17.5413148902351, 27.62236848440967, 34.167432109830635, 33.5530593148597, 24.871989404484708, 22.538985857515478, 19.88345881250015, 19.626536276143046, 24.96533202287205, 26.99008234688366, 30.478756243101024, 18.617213627856266, 21.778753266184, 18.35886720014875, 17.106135455113282, 36.39328780027398, 26.822759108356742, 14.240572588307176, 28.230204859383733, 21.431420188796782, 31.11476430912863, 22.677901176327765, 9.464064816600509, 31.680832645429867, 18.73132975600767, 18.020305765232067, 22.461908205752184]

# %%
## Simple Random Sampling - With Replacement
data = np.random.randint(3, 30, 30)
sample_1 = random.choices(data, k=100)
print(sample_1)
# Out:
# [8, 22, 15, 16, 10, 25, 29, 18, 29, 9, 25, 9, 22, 24, 23, 22, 27, 9, 3, 6, 16, 8, 25, 22, 19, 4, 15, 19, 23, 15, 3, 24, 25, 11, 16, 11, 5, 10, 12, 22, 4, 15, 15, 23, 15, 24, 24, 10, 15, 5, 15, 23, 22, 25, 11, 15, 6, 16, 11, 11, 22, 25, 4, 22, 18, 25, 18, 18, 16, 22, 29, 5, 27, 9, 3, 22, 23, 9, 9, 10, 29, 29, 11, 15, 6, 19, 19, 15, 27, 9, 23, 11, 9, 19, 25, 25, 3, 24, 10, 23]

# %%
## Stratified Sampling
import pandas as pd
df = pd.DataFrame({'Gender': ['F','M', 'F', 'M','F','M', 'M','F','M','M'], 
                   'Purchase_Amount': list(st.norm.rvs(11000, 1000,10))})
df.groupby('Gender').apply(lambda x:x.sample(3,random_state = 0))
# Out:
#          Gender  Purchase_Amount
# Gender
# F      4      F      9181.335525
#        7      F     11917.551169
#        2      F     10002.443459
# M      9      M     11621.257169
#        5      M      9764.493450
#        3      M     11772.586797

# %% [markdown]
# # Estimation - Sample Size and Standard Error

# %% [markdown]
# ## Estimation - Confidence Interval
# ### Estimation of population mean - Sigma is known
# - If a firm takes a sample of 50 salesmen and finds out that the average amount of time each salesman spends with his customers is 80 minutes and population standard deviation is known to be 10 minutes. Estimate the population mean with
#     1. 90%
#     2. 95%
#     3. 99% confidence level

# %%
## a. 90% Confidence Interval CI = xbar +- zalphaby2*std.error
import numpy as np
import scipy.stats as st
n = 50
xbar = 80
sigma = 10
alpha_a = 0.1
zalphaby2 = st.norm.isf(alpha_a/2)
std_error = sigma / np.sqrt(n)
margin_error = zalphaby2 * std_error
lower_cl = xbar - margin_error
higher_cl = xbar + margin_error
(lower_cl, higher_cl)
# Out:
# (77.67382569264666, 82.32617430735334)

# %%
## a. 95% Confidence Interval CI = xbar +- zalphaby2*std.error
alpha_b = 0.05
zalphaby2 = st.norm.isf(alpha_b/2)
std_error = sigma / np.sqrt(n)
margin_error = zalphaby2 * std_error
lower_cl = xbar - margin_error
higher_cl = xbar + margin_error
(lower_cl, higher_cl)
# Out:
# (77.22819235130065, 82.77180764869935)

# %%
## a. 99% Confidence Interval CI = xbar +- zalphaby2*std.error
alpha_c = 0.01
zalphaby2 = st.norm.isf(alpha_c/2)
std_error = sigma / np.sqrt(n)
margin_error = zalphaby2 * std_error
lower_cl = xbar - margin_error
higher_cl = xbar + margin_error
(lower_cl, higher_cl)
# Out:
# (76.35722726456311, 83.64277273543689)

# %% [markdown]
# ### Estimation of population mean - Sigma is unknown
# - Madhu, a student, intends to buy a used bike. After randomly selecting 125 wanted advertisements, he found the average price of the bike to be Rs.32500 with a standard deviation of Rs.6150. Establish an interval estimate for the average price of the bike so that Madhu can be 95.5% certain that the population mean lies in this interval

# %%
# As sigma is unknown so we use another formula for calculating, with the t-distribution
n = 125
xbar = 32500
s = 6150
alpha = 0.45
talphaby2 = st.t.isf(alpha/2, n-1)
std_error = s / np.sqrt(n) 
margin_error = talphaby2 * std_error
lower_cl = xbar - margin_error
higher_cl = xbar + margin_error
(lower_cl, higher_cl)
# Out:
# (32083.147083161486, 32916.852916838514)

# %% [markdown]
# ### Estimation of population proportion
# - Suppose we wish to estimate the proportion of families in a town which have two or more children. A random sample of 144 families shows that 48 families have two or more children. Set up a 95 percent confidence interval estimate of the population proportion of families having two or more children.

# %%
n = 144
x = 48
p = x / n
q = 1 - p
alpha = 0.05
std_error = np.sqrt(p*q/n)
zalphaby2 = st.norm.isf(alpha/2)
margin_error = zalphaby2 * std_error
lower_cl = p - margin_error
higher_cl = p + margin_error
(lower_cl, higher_cl)
# Out:
# (0.25633867642501784, 0.4103279902416488)

# %% [markdown]
# ## Estimation - Sample Size

# %% [markdown]
# - In a random sample of 1000 homes in a city it is found 628 use electric-invertors. If we wish to be 98% confident that our sample proportion will be within 0.05 of the true proportion of homes in this city that use electric-invertors, how large a sample to be considered

# %%
n = 1000
x = 628
alpha = 0.02
margin_error = 0.05
p = x / n
q = 1 - p
sigma = np.sqrt(p * q)
zalphaby2 = st.norm.isf(alpha/2)
n = ((zalphaby2)**2)*(sigma**2)/margin_error**2
n
# Out:
# 505.72205176207603

# %% [markdown]
# - Suppose we want to know the average age of an Florida State College student, plus or minus 0.5 years. We’d like to be 99% confident about our result. From a previous study, we know that the standard deviation for the population is 2.9.

# %%
sigma = 2.9
alpha = 0.01
margin_error = 0.5
zalphaby2 = st.norm.isf(alpha/2)
n = ((zalphaby2**2)*(sigma**2) / (margin_error**2))
n
# Out:
# 223.1979216583537

# %% [markdown]
# # SMOTE - UnderSampling, OverSampling
# ##  (Synthetic Minority Oversampling Technique)
# - SMOTE first selects a minority class instance a at random and finds its k nearest minority class neighbors. The synthetic instance is then created by choosing one of the k nearest neighbors b at random and connecting a and b to form a line segment in the feature space. The synthetic instances are generated as a convex combination of the two chosen instances a and b.

# %%
from IPython.display import Image
Image(filename='Upsampling.png')

# %% [markdown]
# `from sklearn.utils import resample`
# #### Down sampling of majority class
# `xtrain_down,ytrain_down = resample(xtrain[ytrain==0],ytrain[ytrain==0],n_samples = xtrain[ytrain==1].shape[0],random_state=10)`
#
# #### Up sampling of minority class
# `xtrain_up,ytrain_up = resample(xtrain[ytrain==1],ytrain[ytrain==1],n_samples = xtrain[ytrain==0].shape[0],random_state=10)`

# %% [markdown]
# # Introduction to Hypothesis Testing
# - A statistical hypothesis is an assumption about a population parameter. For example, we may assume that the mean height of a male in the U.S. is 70 inches. The assumption about the height is the statistical hypothesis and the true mean height of a male in the U.S. is the population parameter.
# - The Two Types of Statistical Hypotheses
#     1. The null hypothesis, denoted as H0, is the hypothesis that the sample data occurs purely from chance.
#     2. The alternative hypothesis, denoted as H1 or Ha, is the hypothesis that the sample data is influenced by some non-random cause.
#  ## Hypothesis Tests
#  1. State the hypotheses: State the null and alternative hypotheses. These two hypotheses need to be mutually exclusive, so if one is true then the other must be false.
#  2. Determine a significance level to use for the hypothesis.: Decide on a significance level. Common choices are .01, .05, and .1.
#  3. Find the test statistic: Find the test statistic and the corresponding p-value. Often we are analyzing a population mean or proportion and the general formula to find the test statistic is: (sample statistic – population parameter) / (standard deviation of statistic)
#  4. Reject or fail to reject the null hypothesis: Using the test statistic or the p-value, determine if you can reject or fail to reject the null hypothesis based on the significance level. The p-value tells us the strength of evidence in support of a null hypothesis. If the p-value is less than the significance level, we reject the null hypothesis.
#  5. Interpret the results: Interpret the results of the hypothesis test in the context of the question being asked.

# %%
from IPython.display import Image
Image(filename='hypothesis.png')

# %% [markdown]
# ### The Four Assumptions of Parametric Tests
# 1. **Normality – Data in each group should be normally distributed.**
# 2. **Equal Variance – Data in each group should have approximately equal variance.**
# 3. **Independence – Data in each group should be randomly and independently sampled from the population.**
# 4. **No Outliers – There should be no extreme outliers.**

# %%
from IPython.display import Image
Image(filename='p-value.png')

# %%
from IPython.display import Image
Image(filename='introduction-to-ttests-statistics.png')

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# - H0: pop data = Normal
# - H1: pop data != normal

# %%
# For testing the normalisty
import scipy.stats as st
st.shapiro(df.total_bill) # As p-values is less than 0.05 it is highly significant & we reject null hypothesis
# Out:
# ShapiroResult(statistic=0.9197188019752502, pvalue=3.3245434183371003e-10)

# %% [markdown]
# - H0: population_1 variance = population_2 variance
# - H1: population_1 variance != population_2 variance

# %%
tb_m = df[df['sex'] == 'Male']['total_bill']
tb_f = df[df['sex'] == 'Female']['total_bill']

# %%
# For testing the variance
st.levene(tb_m, tb_f) # As p-values is less than 0.05 it is highly significant & we accept null hypothesis
# Out:
# LeveneResult(statistic=1.631715567905501, pvalue=0.20269005267784254)

# %% [markdown]
# # Parametric Test
# ## Testing the population parameter ( one variable must be numerical)
# ## 1. One Sample Test of Mean(Parametric)

# %% [markdown]
# # Q. The manager is stating that on an average the total bill is 20 dollar. Is this statment true ? verify @ 5 % level of siginificance

# %% [markdown]
# - Two tailed test
# - H0 : mu = 25
# - H1 : mu != 25

# %%
mu = 25
xbar = df.total_bill.mean()
s = df.total_bill.std()
std_error = s/np.sqrt(len(df.total_bill))
t_statistics = (xbar - mu) / std_error
t_statistics
# Out:
# -9.148776791224513

# %%
# For positive side
n = len(df.total_bill)
t_critical1 = st.t.isf(alpha/2, n-1)
t_critical1
# Out:
# 1.9697743954258797

# %%
# For negative side
t_critical2 = st.t.ppf(alpha/2, n-1)
t_critical2
# Out:
# -1.9697743954258797

# %% [markdown]
# ### As the test statistics value is way more than the critical value, thats why we reject null hypothesis.

# %%
from IPython.display import Image
Image(filename='test-statistics.png')

# %% [markdown]
# # Q. Test the claim that the average expenditure of bachelors per day is above rs.300. They conducted the survey on 500 bachelors to verfiy the claim whcih they found the sample average is rs.325 with a standard deviation of rs.40. Asume alpha=1%

# %% [markdown]
# - H0 : mu <= 300
# - H1 : mu > 300

# %%
n = 500
xbar = 325
s = 40
alpha = 0.01
mu = 300
std_error = s/ np.sqrt(n)
t_statistics = (xbar - mu) / std_error
t_statistics
# Out:
# 13.975424859373685

# %%
t_critical = st.t.isf(alpha, n-1)
t_critical
# Out:
# 2.3338439936572817

# %%
st.t.interval(1 - alpha, n-1, xbar, std_error)
# Out:
# (320.37452759195156, 329.62547240804844)

# %% [markdown]
# ### As the test statisitcs is far more than critical, we reject null hypothesis. As well from the interval.

# %% [markdown]
# # 2. Two- Sample Independent Test of Mean(Parametric)

# %%
tb_m = df[df['sex'] == 'Male']['total_bill']
tb_f = df[df['sex'] == 'Female']['total_bill']

# %%
x1 = tb_m.mean()
x2 = tb_f.mean()
s1_2 = tb_m.var()
s2_2 = tb_f.var()
n1 = len(tb_m)
n2 = len(tb_f)
pooled_var = ((n1-1)*s1_2 + (n2-1)*s2_2)/(n1 + n2 - 2)
std_error = np.sqrt(pooled_var*((1/n1)+(1/n2)))
t_st = (x1-x2)/std_error
t_crit = st.t.isf(alpha/2, n1 + n2 -2)
print(t_st, t_crit)
# Out:
# 2.2777940289803253 1.9698151341345516

# %%
p_value = st.t.sf(t_st,n1 + n2 - 2)*2
p_value
# Out:
# 0.023611666846858698

# %%
st.ttest_ind(tb_f, tb_m, equal_var = True)
# Out:
# Ttest_indResult(statistic=-2.2777940289803134, pvalue=0.0236116668468594)

# %% [markdown]
# # 3. Paired t-Test

# %% [markdown]
# # Q. Test whether drug is effective or not for the following sample data on 10 patients of sugar level. The data is captured before the drug and after the drug.

# %%
np.random.seed(2)
sugarlevel_before = np.random.randint(150, 300, 10)
sugarlevel_before
# Out:
# array([165, 222, 172, 193, 225, 254, 157, 245, 225, 197])

# %%
np.random.seed(2)
sugarlevel_after = np.random.randint(150, 200, 10)
sugarlevel_after
# Out:
# array([190, 165, 195, 158, 172, 193, 168, 161, 190, 157])

# %%
diff = sugarlevel_before - sugarlevel_after
diff
# Out:
# array([-25,  57, -23,  35,  53,  61, -11,  84,  35,  40])

# %%
# Test for Normality
st.shapiro(diff)
# Out:
# ShapiroResult(statistic=0.8972954750061035, pvalue=0.20456258952617645)

# %% [markdown]
# - H0: mu_before = mu_after     (where mu is sugarlevel)     mu_diff = 0
# - H1: mu_before != mu_after    mu_diff != 0

# %%
mu_diff = 0
dbar = diff.mean()
s = diff.std(ddof = 1)
n = len(diff)
alpha = 0.05
se = s/np.sqrt(n)
t_stats = (dbar - mu_diff)/se
t_critical = st.t.isf(alpha/2, n-1)
print('t_stats =', t_stats,';','t_critical =', t_critical)
# Out:
# t_stats = 2.5662489083115965 ; t_critical = 2.262157162740992

# %%
print(st.t.sf(t_stats, n-1)*2)
# Out:
# 0.030374136971356682

# %%
st.ttest_rel(sugarlevel_before,sugarlevel_after)
# Out:
# Ttest_relResult(statistic=2.5662489083115965, pvalue=0.030374136971356682)

# %% [markdown]
# # 4. ANOVA

# %% [markdown]
# # Q. Is the total bill is same for all the days? pls verify @ 5% level of significance?( refer to 'tips' data set )

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# %%
tb_Thrusday = df[df['day'] == 'Thru']['total_bill']
tb_Friday = df[df['day'] == 'Fri']['total_bill']
tb_Saturday = df[df['day'] == 'Sat']['total_bill']
tb_Sunday = df[df['day'] == 'Sun']['total_bill']

# %%
# Ols
model1 = ols('total_bill~day', data = df).fit()
anova_table = anova_lm(model1)
anova_table
# Out:
#              df        sum_sq     mean_sq         F    PR(>F)
# day         3.0    643.941362  214.647121  2.767479  0.042454
# Residual  240.0  18614.522721   77.560511       NaN       NaN

# %% [markdown]
# ### Since p-value is less than alpha, we reject null hypothesis, that is, the total bill is not same for all the days.

# %% [markdown]
# # Non-Parametric Test
# ## Testing the relationship (applicable for categorical variables)

# %% [markdown]
# ## 1. One Sample Test of Median(Non - Parametric)
# ## Wilcoxon Test

# %% [markdown]
# ### Test of Median
#
# - Ho: population median_total bill >= 25
# - H1 : population median_total bill < 25

# %%
pop_median = 25
alpha = 0.05
diff_median =  df.total_bill - pop_median

# %%
# Wilcoxon test
st.wilcoxon(diff_median, alternative = 'less')
# Out:
# WilcoxonResult(statistic=5726.5, pvalue=5.5158121274466396e-17)

# %% [markdown]
# # 2. Two- Sample Independent Test of Median(Non- Parametric)
# ##  Mann Whitney U test
#
# - Ho: population median tb_f = population median tb_m
# - H1: population median tb_f != population median tb_m

# %%
tb_m = df[df['sex'] == 'Male']['total_bill']
tb_f = df[df['sex'] == 'Female']['total_bill']

# %%
st.mannwhitneyu(tb_f, tb_m)
# Out:
# MannwhitneyuResult(statistic=5613.5, pvalue=0.021350332087987117)

# %% [markdown]
# ### Since p-value is less than alpha, we reject null hypothesis. That is, the population median is not same for two independent samples.

# %% [markdown]
# # 3. Wilcoxon signed rank test

# %% [markdown]
# - H0: Population median_before = Population median_after     Mu_diff = 0
# - H1: Population median_before != Population median_after     Mu_diff != 0

# %%
st.wilcoxon(sugarlevel_after, sugarlevel_before)
# Out:
# WilcoxonResult(statistic=6.0, pvalue=0.02734375)

# %% [markdown]
# ### As p-value is less than alpha, we reject null hypothesis.

# %% [markdown]
# ## 4. Kruskal Wallis Test

# %% [markdown]
# - H0: pop medians of all the days are equal
# - H1: Atleast one pop median is different from others

# %%
tb_Th= df[df.day=='Thur']['total_bill']
tb_Fri= df[df.day=='Fri']['total_bill']
tb_Sat= df[df.day=='Sat']['total_bill']
tb_Sun= df[df.day=='Sun']['total_bill']

# %%
st.kruskal(tb_Th,tb_Fri,tb_Sat,tb_Sun)
# Out:
# KruskalResult(statistic=10.403076391437086, pvalue=0.01543300820104127)

# %% [markdown]
# ### As p-value is less than alpha, we reject null hypothesis.

# %% [markdown]
# # Two samples Test of Proportion

# %% [markdown]
# # Q. Test whether the smoking population is different from male and female.
#
# - H0: P_male = P_female   mu_diff = 0
# - H1: P_male != P_female   mu_diff != 0

# %%
pd.crosstab(df.sex, df.smoker)
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
alpha = 0.05
n = len(df.smoker)
P_diff = 0
xm = 60
nm = 157
pm = xm/nm
xf = 33
nf = 87
pf = xf/nf
p = (xm + xf) / (nm + nf)
q = 1 - p
se = np.sqrt(p*q*((1/nm)+(1/nf)))
z_st = ((pm-pf)-(P_diff))/se
z_crit = st.norm.isf(alpha/2)
print(z_st, z_crit)
# Out:
# 0.043986572230939734 1.9599639845400545

# %%
st.norm.sf(z_st)*2
# Out:
# 0.9649151073157315

# %%
from statsmodels.stats.proportion import proportions_ztest
proportions_ztest([xm, xf], [nm, nf])
# Out:
# (0.043986572230939734, 0.9649151073157315)

# %% [markdown]
# ### As p-value is greater than alpha we accept null hypothesis.

# %% [markdown]
# # Chi Square

# %% [markdown]
# # Q. Is there any association b/w smoking and day?

# %% [markdown]
# - H0: There is no association or independency b/w smoking & day
# - H0: There is an association or dependency b/w smoking & day

# %%
table = pd.crosstab(df.smoker, df.day)
table
# Out:
# day     Thur  Fri  Sat  Sun
# smoker
# Yes       17   15   42   19
# No        45    4   45   57

# %%
st.chi2_contingency(table)
# Out:
# (25.787216672396262,
#  1.0567572499836523e-05,
#  3,
#  array([[23.63114754,  7.24180328, 33.15983607, 28.96721311],
#         [38.36885246, 11.75819672, 53.84016393, 47.03278689]]))

# %% [markdown]
# ### As p-value is less than alpha, we reject null hypothesis, there is an association between two variable.

# %% [markdown]
# # Coveriance and Correlation

# %% [markdown]
# ## Covariance
# - Covariance is a measure of the relationship between two random variables and to what extent, they change together. Or we can say, in other words, it defines the changes between the two variables, such that change in one variable is equal to change in another variable. This is the property of a function of maintaining its form when the variables are linearly transformed. Covariance is measured in units, which are calculated by multiplying the units of the two variables.

# %%
df.cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.heatmap(df.cov(), annot = True, xticklabels = ['Total Bill', 'Tip', 'Size'], 
            yticklabels = ['Total Bill', 'Tip', 'Size'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Correlation
# - In statistics, Correlation studies and measures the direction and extent of relationship among variables, so the correlation measures co-variation, not causation. Therefore, we should never interpret correlation as implying cause and effect relation. For example, there exists a correlation between two variables X and Y, which means the value of one variable is found to change in one direction, the value of the other variable is found to change either in the same direction (i.e. positive change) or in the opposite direction (i.e. negative change). Furthermore, if the correlation exists, it is linear, i.e. we can represent the relative movement of the two variables by drawing a straight line on graph paper.

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(), annot = True, xticklabels = ['Total Bill', 'Tip', 'Size'], 
            yticklabels = ['Total Bill', 'Tip', 'Size'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Spearman, Kendall, Pearson
# 1. **Pearson Correlation(parametric)**: Tests for the strength of the association between two continuous variables.
# 2. **Spearman Correlation(non-parametric)**: Tests for the strength of the association between two ordinal variables (does not rely on the assumption of normally distributed data).
# 3. **Kendall Correlation(non-parametric)**: Kendall rank correlation (non-parametric) is an alternative to Pearson’s correlation (parametric) when the data you’re working with has failed one or more assumptions of the test. This is also the best alternative to Spearman correlation (non-parametric) when your sample size is small and has many tied ranks.

# %% [markdown]
# # Q. Hypothesis Test to check the correlation on population
#
# ## Total_bill and tip
#
# - H0: There is no realtion b/w total_bill and tip(r = 0)
# - H1: There is a realtion b/w total_bill and tip(r!= 0)

# %%
st.pearsonr(df.total_bill, df.tip)
# Out:
# (0.6757341092113647, 6.6924706468630016e-34)

# %% [markdown]
# ### As p-value is less than alpha, we reject null hypothesis.

# %% [markdown]
# # Correlation Coefficient
# - Correlation Coefficient is a statistical concept, which helps in establishing a relation between predicted and actual values obtained in a statistical experiment. The calculated value of the correlation coefficient explains the exactness between the predicted and actual values.
# - Correlation Coefficient value always lies between -1 to +1. If correlation coefficient value is positive, then there is a similar and identical relation between the two variables. Else it indicates the dissimilarity between the two variables.
# - The covariance of two variables divided by the product of their standard deviations gives Pearson’s correlation coefficient. It is usually represented by ρ (rho).
# - ρ (X,Y) = cov (X,Y) / σX.σY.
# - Here cov is the covariance. σX is the standard deviation of X and σY is the standard deviation of Y. The given equation for correlation coefficient can be expressed in terms of means and expectations.

# %% [markdown]
# # Introduction to Regression
# - Linear regression strives to show the relationship between two variables by applying a linear equation to observed data. One variable is supposed to be an independent variable, and the other is to be a dependent variable. For example, the weight of the person is linearly related to his height. Hence this shows a linear relationship between the height and weight of the person. As the height is increased, the weight of the person also gets increased.
# - The measure of the extent of the relationship between two variables is shown by the correlation coefficient. The range of this coefficient lies between -1 to +1. This coefficient shows the strength of the association of the observed data for two variables.
# - Y = B0+B1X
# - Where
#     - B0 is a constant
#     - B1 is the regression coefficient
#     - Now, let us see the formula to find the value of the regression coefficient.
#     - B1 = b1 = Σ [ (xi – x)(yi – y) ] / Σ [ (xi – x)2]
#     - Where xi and yi are the observed data sets.
#     - And x and y are the mean value.

# %%
np.random.seed(0)
marks = pd.Series([60,70,89,17,93,78,23,91,11,38])
s_hours= pd.Series([21,45,50,8,55,43,7,60,10,33])

# %%
dfs= pd.DataFrame({'marks':marks, 's_hours': s_hours})
dfs.head()
# Out:
#    marks  s_hours
# 0     60       21
# 1     70       45
# 2     89       50
# 3     17        8
# 4     93       55

# %%
sns.heatmap(dfs.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from statsmodels.formula.api import ols
models = ols('marks~s_hours', data=dfs).fit()
models.summary()
# Out:
# /home/mukhtarmid/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  marks   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     58.73
# Date:                Tue, 07 Jun 2022   Prob (F-statistic):           5.94e-05
# Time:                        16:04:58   Log-Likelihood:                -37.774
# No. Observations:                  10   AIC:                             79.55
# Df Residuals:                       8   BIC:                             80.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# 1. Durbin-Watson
# 2. Jarque-Bera
# 3. Cond. No
# 4. Omnibus

# %%
## predict the marks for a studnet whose study hours = 35?
x= pd.DataFrame({'s_hours': [35,45,23,0,100]})

# %%
models.predict(x)
# Out:
# 0     59.674159
# 1     74.530595
# 2     41.846435
# 3      7.676632
# 4    156.240994
# dtype: float64

# %% [markdown]
# # Binary Logistic Regression
# - Logistic regression measures the relationship between the categorical target variable and one or more independent variables. It is useful for situations in which the outcome for a target variable can have only two possible types (in other words, it is binary). Binary Logistic Regression Classification makes use of one or more predictor variables that may be either continuous or categorical to predict the target variable classes. This technique helps to identify important factors (Xi) impacting the target variable (Y) and also the nature of the relationship between each of these factors and the dependent variable.
